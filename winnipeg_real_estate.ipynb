# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df_real_estate = pd.read_csv('data/Detailed_Building_Permit_Data.csv')
# Out:
# /var/folders/g6/9vrytjqx3y7bwvrfmb4qkt440000gn/T/ipykernel_49881/3085551931.py:1: DtypeWarning: Columns (22,23,24,25,26,28,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_real_estate = pd.read_csv('data/Detailed_Building_Permit_Data.csv')

# %%
df_real_estate.head()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Issue Date</th>
#       <th>Permit Number</th>
#       <th>Parent Permit Number</th>
#       <th>Permit Group</th>
#       <th>Permit Type</th>
#       <th>Sub Type</th>
#       <th>Work Type</th>
#       <th>Street Number</th>
#       <th>Street Name</th>
#       <th>Street Type</th>
#       <th>Street Direction</th>
#       <th>Unit Type</th>
#       <th>Unit Number</th>
#       <th>Neighbourhood Number</th>
#       <th>Neighbourhood Name</th>
#       <th>Community</th>
#       <th>Applicant Business Name</th>
#       <th>Dwelling Units Created</th>
#       <th>Dwelling Units Lost</th>
#       <th>Location</th>
#       <th>X Coordinate NAD83</th>
#       <th>Y Coordinate NAD83</th>
#       <th>Includes Secondary Suite</th>
#       <th>Adding Secondary Suite</th>
#       <th>Removing Secondary Suite</th>
#       <th>Pool Type</th>
#       <th>Type of Structure</th>
# ...

# %%
df_real_estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134046 entries, 0 to 134045
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Issue Date                 134046 non-null  object
#  1   Permit Number              134046 non-null  object
#  2   Parent Permit Number       9548 non-null    object
#  3   Permit Group               134046 non-null  object
#  4   Permit Type                134046 non-null  object
#  5   Sub Type                   134046 non-null  object
#  6   Work Type                  134044 non-null  object
#  7   Street Number              133759 non-null  float64
#  8   Street Name                133776 non-null  object
#  9   Street Type                133021 non-null  object
#  10  Street Direction           7120 non-null    object
#  11  Unit Type                  7095 non-null    object
#  12  Unit Number                7964 non-null    object
# ...

# %%
df = df_real_estate.drop(['Street Direction', 'Unit Type', 'Unit Number', 'Type of Structure', 'Pool Type', 'ICR Start Date', 'ICR Complete Date', 'ICR Work Days', 'X Coordinate NAD83', 'Y Coordinate NAD83', 'Includes Secondary Suite', 'Adding Secondary Suite', 'Removing Secondary Suite', 'Point', 'Location'], axis=1).copy()

# %%
df.nunique()
# Out:
# Issue Date                     3499
# Permit Number                134046
# Parent Permit Number           5586
# Permit Group                      2
# Permit Type                      16
# Sub Type                        188
# Work Type                        36
# Street Number                  2972
# Street Name                    3912
# Street Type                      36
# Neighbourhood Number            237
# Neighbourhood Name              240
# Community                         6
# Applicant Business Name       13776
# Dwelling Units Created          148
# Dwelling Units Lost              21
# Ward                             15
# Application Received Date      4193
# Status                            3
# Final Date                     3665
# dtype: int64
